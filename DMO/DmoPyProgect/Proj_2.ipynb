# %%
import pandas as pd
import numpy as np

df = pd.read_csv('/home/dami/Progetti_unifi/DMO/Dataset/Dataset CdS3+CdS4_2.csv', sep= ';')
df
# Out:
#      Unnamed: 0 degree  cohort gender school   test  total_cfu  total_cfu_g  \
# 0             0   CdS3    2010      M     LS  15.00         32           30
# 1             1   CdS3    2010      M     LS  10.00         14           12
# 2             2   CdS3    2010      F     LC   8.00         24           24
# 3             3   CdS3    2010      F     LS  16.00         39           39
# 4             4   CdS3    2010      M     AL  12.00          6            6
# ..          ...    ...     ...    ...    ...    ...        ...          ...
# 527         527   CdS4    2016      F     LL   5.50         27           24
# 528         528   CdS4    2016      M     IT   8.25         39           36
# 529         529   CdS4    2016      M     LS   3.75         48           48
# 530         530   CdS4    2016      M     IT   3.75         12           12
# 531         531   CdS4    2016      F     LL   1.25         51           48
#
#      avg_g  math_course_g math_course_d  EsitoTest
# ...

# %%
del df["Unnamed: 0"]

# %%
df
# Out:
#     degree  cohort gender school   test  total_cfu  total_cfu_g  avg_g  \
# 0     CdS3    2010      M     LS  15.00         32           30     25
# 1     CdS3    2010      M     LS  10.00         14           12     27
# 2     CdS3    2010      F     LC   8.00         24           24     28
# 3     CdS3    2010      F     LS  16.00         39           39     26
# 4     CdS3    2010      M     AL  12.00          6            6     27
# ..     ...     ...    ...    ...    ...        ...          ...    ...
# 527   CdS4    2016      F     LL   5.50         27           24     28
# 528   CdS4    2016      M     IT   8.25         39           36     23
# 529   CdS4    2016      M     LS   3.75         48           48     21
# 530   CdS4    2016      M     IT   3.75         12           12     26
# 531   CdS4    2016      F     LL   1.25         51           48     23
#
#      math_course_g math_course_d  EsitoTest
# 0               21    2011-02-25          1
# ...

# %%
y = df.Type
COVARIATE = ['degree', 'cohort', 'gender', 'school', 'EsitoTest','Price']
X = df[COVARIATE]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-f1c3f2d4921b> in <module>
# ----> 1 y = df.Type
#       2 COVARIATE = ['degree', 'cohort', 'gender', 'school', 'EsitoTest','Price']
#       3 X = df[COVARIATE]
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Type'

# %%
ciao =((df.avg_g)/(30))*(df.total_cfu_g)
ciao
# Out:
# 0      25.0
# 1      10.8
# 2      22.4
# 3      33.8
# 4       5.4
#        ...
# 527    22.4
# 528    27.6
# 529    33.6
# 530    10.4
# 531    36.8
# Length: 532, dtype: float64
