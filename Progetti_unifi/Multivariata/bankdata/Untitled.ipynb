# %%
import numpy as pd

# %%
n, p, size = 5, 0.6, 1000
pd.random.binomial(n, p, size)
# Out:
# array([2, 4, 5, 5, 3, 5, 1, 2, 3, 4, 4, 5, 5, 4, 3, 4, 2, 1, 1, 3, 3, 1,
#        1, 4, 3, 3, 3, 5, 2, 3, 4, 4, 5, 1, 2, 1, 4, 3, 4, 4, 2, 4, 4, 3,
#        3, 0, 5, 4, 2, 4, 4, 2, 3, 4, 2, 3, 4, 3, 3, 2, 3, 3, 4, 4, 2, 4,
#        3, 4, 4, 3, 3, 4, 2, 2, 4, 1, 4, 3, 2, 4, 2, 1, 3, 3, 5, 1, 3, 4,
#        3, 4, 3, 3, 3, 2, 4, 4, 4, 2, 4, 4, 3, 2, 2, 3, 5, 2, 3, 2, 1, 3,
#        1, 3, 3, 3, 5, 1, 2, 2, 2, 4, 3, 2, 2, 3, 4, 3, 4, 1, 5, 3, 1, 4,
#        2, 4, 4, 3, 3, 4, 4, 5, 4, 4, 3, 3, 2, 5, 3, 4, 2, 2, 3, 3, 4, 4,
#        3, 3, 2, 2, 4, 3, 1, 3, 4, 2, 3, 3, 3, 3, 3, 2, 3, 2, 3, 3, 2, 3,
#        3, 4, 1, 1, 4, 3, 4, 4, 4, 3, 3, 2, 1, 3, 2, 3, 3, 3, 3, 4, 0, 4,
#        4, 3, 2, 1, 1, 3, 4, 5, 3, 3, 3, 4, 2, 1, 2, 5, 4, 4, 0, 1, 3, 4,
#        2, 2, 3, 2, 3, 3, 3, 2, 3, 3, 3, 4, 3, 3, 3, 4, 2, 3, 3, 1, 3, 3,
#        4, 4, 2, 3, 5, 4, 3, 2, 2, 4, 4, 3, 2, 3, 3, 5, 3, 3, 4, 3, 4, 4,
#        4, 2, 4, 1, 3, 3, 2, 2, 4, 3, 5, 4, 2, 4, 2, 3, 4, 4, 2, 0, 2, 3,
# ...
